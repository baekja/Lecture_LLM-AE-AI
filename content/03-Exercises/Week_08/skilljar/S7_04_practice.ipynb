# %% [markdown]
# # S7_04: 학생 실습 — CLAUDE.md 작성 + CPI 패턴
#
# **Building with the Claude API — Section 7, 학생 실습 노트북**
#
# 이 노트북에서는 직접 CLAUDE.md를 작성하고, Claude Code의 Context → Plan → Implement 패턴을 실습합니다.
#
# ---
#
# ## 학습 목표
# - 프로젝트에 적합한 CLAUDE.md를 직접 작성할 수 있다
# - CPI 패턴을 이해하고 적용할 수 있다
# - Claude Code의 주요 명령어를 활용할 수 있다

# %% [markdown]
# ## 실습 1: CLAUDE.md 작성
#
# ### 과제
# 아래 프로젝트 정보를 바탕으로 CLAUDE.md를 작성하세요.
#
# **프로젝트 정보:**
# - 프로젝트명: KDS 기준 RC 보 설계 검토 시스템
# - 기술 스택: Python 3.11, FastAPI, Streamlit, ChromaDB, Claude API
# - 디렉토리: src/api/, src/calculators/, src/rag/, src/ui/, tests/
# - 빌드 명령: pip install, uvicorn, streamlit run, pytest
# - 도메인: 건축구조 (KDS 14 20 20)
#
# ### 작성 공간

# %%
# 실습 1: CLAUDE.md 내용을 문자열로 작성하세요
my_claude_md = """
# CLAUDE.md

## 프로젝트 개요
# TODO: 프로젝트 설명을 작성하세요

## 기술 스택
# TODO: 사용 기술을 나열하세요

## 디렉토리 구조
# TODO: 디렉토리와 역할을 정리하세요

## 빌드 및 실행
# TODO: 주요 명령어를 작성하세요

## 도메인 규칙
# TODO: 단위 시스템, 기준 코드 등을 작성하세요

## 코딩 컨벤션
# TODO: 코딩 규칙을 작성하세요
"""

print(my_claude_md)

# %% [markdown]
# ### 체크리스트
#
# - [ ] 프로젝트 개요가 명확한가?
# - [ ] 기술 스택이 빠짐없이 나열되었는가?
# - [ ] 디렉토리 구조와 각 역할이 설명되었는가?
# - [ ] 빌드/실행 명령어가 바로 실행 가능한가?
# - [ ] 도메인 규칙 (단위, 기준코드)이 포함되었는가?
# - [ ] 코딩 컨벤션이 구체적인가?

# %% [markdown]
# ## 실습 2: CPI 패턴 실습
#
# ### 과제
# 아래 시나리오에 대해 Claude Code에게 보낼 프롬프트를 CPI 패턴으로 작성하세요.
#
# **시나리오**: RC 보의 전단 강도 검토 함수를 추가하려고 합니다.

# %%
# 실습 2: CPI 패턴 프롬프트 작성

# Context 단계 프롬프트
context_prompt = """
# TODO: 프로젝트 파악을 위한 프롬프트를 작성하세요
# 예시: "src/calculators/ 디렉토리의 기존 계산 모듈을 확인하고..."
"""

# Plan 단계 프롬프트
plan_prompt = """
# TODO: 구현 계획을 요청하는 프롬프트를 작성하세요
# 핵심: "아직 코드를 작성하지 마. 계획만 세워줘."
"""

# Implement 단계 프롬프트
implement_prompt = """
# TODO: 구현을 지시하는 프롬프트를 작성하세요
# 핵심: 구체적 요구사항 + 테스트 요청
"""

print("=== Context ===")
print(context_prompt)
print("=== Plan ===")
print(plan_prompt)
print("=== Implement ===")
print(implement_prompt)

# %% [markdown]
# ## 실습 3: Claude Code 명령어 퀴즈
#
# 각 상황에 적합한 슬래시 명령어를 작성하세요.

# %%
# 실습 3: 슬래시 명령어 퀴즈
quiz = {
    "새 프로젝트를 처음 시작할 때 CLAUDE.md를 자동 생성하려면?": "",  # TODO
    "긴 대화로 컨텍스트가 부족할 때 대화를 요약하려면?": "",  # TODO
    "현재 세션의 토큰 사용량을 확인하려면?": "",  # TODO
    "완전히 새로운 작업을 시작하기 위해 대화를 초기화하려면?": "",  # TODO
    "사용 중인 모델을 변경하려면?": "",  # TODO
}

for question, answer in quiz.items():
    print(f"Q: {question}")
    if answer:
        print(f"A: {answer}")
    else:
        print("A: [TODO - 답을 작성하세요]")
    print()

# %% [markdown]
# ## 실습 4: 터미널 실습 (수업 시간)
#
# ### 수행 순서
# 1. 새 프로젝트 디렉토리 생성
# 2. `claude` 실행
# 3. `/init`으로 CLAUDE.md 생성
# 4. CLAUDE.md 수정 요청 (건축공학 도메인 정보 추가)
# 5. CPI 패턴으로 간단한 기능 구현 요청
# 6. `/cost`로 비용 확인
#
# ```bash
# # 터미널에서 실행
# mkdir ~/structural-review-practice
# cd ~/structural-review-practice
# git init
# claude
#
# # Claude Code 세션 내:
# > /init
# > CLAUDE.md에 건축공학 도메인 정보를 추가해줘. KDS 기준, 단위 시스템, 변수 네이밍 규칙.
# > /cost
# ```

# %% [markdown]
# ---
#
# ## 참고 자료
# - 강의노트: Week_08.md §1.3, §2.1~2.3
# - [CLAUDE.md Best Practices](https://docs.anthropic.com/en/docs/claude-code/memory)
# - [Claude Code Overview](https://docs.anthropic.com/en/docs/claude-code/overview)
