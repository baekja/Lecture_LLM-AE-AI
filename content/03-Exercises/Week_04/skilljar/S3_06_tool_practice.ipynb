# %% [markdown]
# # Tool Use 실습 — 처음부터 구현하기
#
# 이 노트북은 Tool Use의 전체 흐름을 **직접 구현**하는 연습용 템플릿입니다.
# S3_01 ~ S3_05에서 배운 내용을 떠올리며, 빈 셀을 채워 보세요.
#
# **구현 목표**: 현재 날짜/시간을 조회하는 도구를 만들고, 멀티턴 대화 루프까지 완성하기

# %% [markdown]
# ## 환경 설정
#
# 필요한 라이브러리를 임포트하고 Anthropic 클라이언트를 초기화합니다.

# %%
# ── Setup ──────────────────────────────────────────────
import anthropic
from datetime import datetime
from dotenv import load_dotenv

load_dotenv()

client = anthropic.Anthropic()
MODEL = "claude-haiku-4-5"

# %% [markdown]
# ## Step 1: 도구 함수 작성
#
# `get_current_datetime(date_format)` 함수를 작성하세요.
# `date_format` 파라미터로 출력 형식을 지정하며, 기본값은 `"%Y-%m-%d %H:%M:%S"`입니다.
# 유효하지 않은 포맷이 들어오면 `ValueError`를 발생시키세요.

# %% [markdown]
# ## Step 2: 도구 스키마 정의
#
# 위 함수에 대응하는 JSON Schema를 작성하세요.
# 스키마에는 `name`, `description`, `input_schema`(properties, required) 필드가 필요합니다.
# `tools` 리스트에 스키마를 담아 두세요.

# %% [markdown]
# ## Step 3: 도구 활성화 API 호출
#
# `client.messages.create()`에 `tools` 파라미터를 전달하여 호출하세요.
# 사용자 메시지는 `"지금 몇 시야?"`로 테스트합니다.
# `stop_reason`과 응답 블록의 `type`, `name`, `input`을 출력하세요.

# %% [markdown]
# ## Step 4: 메시지 블록 처리
#
# 응답의 `content` 블록을 순회하면서 `tool_use` 블록을 찾아 실제 함수를 실행하세요.
# 실행 결과를 `tool_result` 딕셔너리로 구성합니다.
# 필요한 키: `type`, `tool_use_id`, `content`

# %% [markdown]
# ## Step 5: tool_result 전송
#
# Step 3의 응답(assistant)과 Step 4의 tool_result(user)를 messages에 추가한 뒤,
# 다시 `client.messages.create()`를 호출하여 Claude의 최종 답변을 받으세요.
# 이번에는 `stop_reason`이 `"end_turn"`이어야 합니다.

# %% [markdown]
# ## Step 6: 멀티턴 대화 루프
#
# `run_conversation(user_message, tools)` 함수를 작성하세요.
# `stop_reason`이 `"tool_use"`인 동안 도구 실행 → 결과 전달을 반복하고,
# 최종 텍스트 응답이 나오면 루프를 종료합니다.

# %% [markdown]
# ## 테스트
#
# 완성한 `run_conversation()`으로 아래 질문을 테스트하세요:
# **"What is the exact time right now?"**
