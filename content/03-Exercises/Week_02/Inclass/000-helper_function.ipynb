# %%
from dotenv import load_dotenv
load_dotenv()
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# === 헬퍼 함수 ===

def add_user_message(messages: list, text: str):
    """사용자 메시지를 대화 이력에 추가"""
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages: list, text: str):
    """어시스턴트 응답을 대화 이력에 추가"""
    messages.append({"role": "assistant", "content": text})

def chat(messages: list, system: str = None) -> str:
    """대화 이력을 전송하고 응답 텍스트를 반환"""
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }
    if system:
        params["system"] = system
    response = client.messages.create(**params)
    return response.content[0].text

# %%
# === 멀티턴 대화 예시 ===
messages = []

# 1턴: 사용자 질문
add_user_message(messages, "RC 보의 설계에서 최소 철근비의 의미가 뭐야?")
response = chat(messages)
add_assistant_message(messages, response)
print(f"Claude: {response}\n")

# 2턴: 후속 질문 (이전 맥락 활용)
add_user_message(messages, "그렇다면 KDS 기준에서 최소 철근비 산정 공식은?")
response = chat(messages)
add_assistant_message(messages, response)
print(f"Claude: {response}\n")

# 3턴: 추가 질문
add_user_message(messages, "fck=30MPa, fy=400MPa일 때 실제로 계산해줘.")
response = chat(messages)
add_assistant_message(messages, response)
print(f"Claude: {response}")
# Out:
# Claude: RC 보에서 **최소 철근비**는 구조적 안전성과 성능을 확보하기 위해 반드시 배치해야 하는 최소한의 철근량을 의미합니다.
#
# ## 주요 의미와 목적
#
# ### 1. **급작스러운 파괴 방지**
# - 콘크리트가 균열되는 순간 철근이 즉시 하중을 받아 급격한 파괴를 방지
# - 연성적 거동을 유도하여 구조물의 안전성 확보
#
# ### 2. **최소한의 휨 강도 확보**
# - 무근 콘크리트의 균열 모멘트보다 큰 공칭 휨 강도 보장
# - 구조물의 기본적인 하중 저항 능력 확보
#
# ### 3. **수축 및 온도 균열 제어**
# - 건조수축, 온도변화로 인한 균열 발생 시 균열폭 제어
# - 장기적인 구조 성능 유지
#
# ## 설계기준값
#
# **KDS 기준 (2021)**
# - 최소 인장철근비: **ρ_min = 0.25√f_ck/f_y** (단, 0.0015 이상)
# - 여기서 f_ck는 콘크리트 압축강도, f_y는 철근 항복강도
#
# ## 실무적 중요성
#
# 최소 철근비를 준수하지 않으면:
# - 예고 없는 급작스러운 파괴
# - 과도한 균열 발생
# - 구조물의 사용성 저하
# - 내구성 문제 발생
#
# 따라서 계산된 필요 철근량이 최소 철근비보다 작더라도, 반드시 최소 철근비 이상으로 설계해야 합니다.
#
# Claude: KDS 기준에서 RC 보의 최소 철근비 산정 공식은 다음과 같습니다.
#
# ## KDS 14 20 52 (2021) 기준
#
# ### **최소 인장철근비**
#
# ```
# ρ_min = max { 0.25√f_ck/f_y , 1.4/f_y }
# ```
#
# **여기서:**
# - ρ_min : 최소 인장철근비
# - f_ck : 콘크리트의 압축강도 (MPa)
# - f_y : 철근의 항복강도 (MPa)
#
# ### **계산 예시**
#
# **조건:** f_ck = 24 MPa, f_y = 400 MPa
#
# 1) **첫 번째 조건:** 0.25√f_ck/f_y
#    - = 0.25√24/400
#    - = 0.25 × 4.899/400
#    - = **0.00306**
#
# 2) **두 번째 조건:** 1.4/f_y
#    - = 1.4/400
#    - = **0.0035**
#
# **결과:** ρ_min = max(0.00306, 0.0035) = **0.0035**
#
# ### **추가 규정**
#
# - **T형 보의 경우:** 웨브 부분에만 적용
# - **프리스트레스트 콘크리트:** 별도 규정 적용
# - **특수 구조물:** 추가적인 검토 필요
#
# 이 공식을 통해 구조물의 안전성과 사용성을 확보하는 최소한의 철근량을 결정합니다.
#
# Claude: **주어진 조건:**
# - f_ck = 30 MPa
# - f_y = 400 MPa
#
# ## KDS 기준 최소 철근비 계산
#
# ### **공식:** ρ_min = max { 0.25√f_ck/f_y , 1.4/f_y }
#
# ### **1단계: 첫 번째 조건 계산**
# ```
# 0.25√f_ck/f_y = 0.25√30/400
# ```
#
# - √30 = 5.477
# - 0.25 × 5.477 = 1.369
# - 1.369/400 = **0.003423**
#
# ### **2단계: 두 번째 조건 계산**
# ```
# 1.4/f_y = 1.4/400 = 0.0035
# ```
#
# ### **3단계: 최대값 선택**
# ```
# ρ_min = max(0.003423, 0.0035) = 0.0035
# ```
#
# ## **최종 결과**
#
# **ρ_min = 0.0035 = 0.35%**
#
# ### **실무 적용**
# 예를 들어, 보의 단면이 300mm × 500mm (b × h)이고 유효깊이 d = 450mm인 경우:
#
# **필요 최소 철근량:**
# As_min = ρ_min × b × d = 0.0035 × 300 × 450 = **472.5 mm²**
#
# 이는 D16 철근 약 3개 (As = 603 mm²) 또는 D13 철근 4개 (As = 531 mm²)에 해당합니다.
